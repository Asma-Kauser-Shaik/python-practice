# %% [markdown]
# # Python

# %% [markdown]
# ### Python
# . python is developed by Gudio Van Rossium in 1991
# . python is highlevel langunage,general purpose programming.
# . python is simple and readable.
# ### Features:
# .High level langangue = programmer does not need to manage memory directly.
# .Easy to learn = simple syntax
# .Interputed = code is executed in python interpreted.
# .portable = runs on windows and macos
# .Object Oriented = its supports the class ,objects.
# .Large libaries = many built- in and extenal libaries are avalible.
# . open source = freely available.
# .Dynamically typed = variable type is decided at runtime.
# ### Uses
# . Web Development
# . ML
# . AI
# . DS
# . computer vision
# . Automation
# . software Developmemnt
# . scientific computing
# ### Applications
# . instagram
# . facebook
# . netflix
# . Quora
# . Filpkart
# . Amazon
# ### Interview ques:
# 1. python is pure OOPL or not ?
# Ans : Not pure but  python is oopl.
# java is pure oopl
# c is producer oopl.
# 2. python is case sensitive or not ?
# Ans: yes python is case sensitive.
# 3. python is complier or interpreter?
# Ans: both python is complier and interpreter.
#        Source code
#            |
#        complier (complier convert code into highlevel langauge into low level language)
#            |
#        Byte code
#            |
#         PVM(python virtual machince)(interperter = complier the code line by line)
#            |
#         machince code
# 4. python is platform  independent language or not ?
# Ans : yes platform independent because of PVM (it can run any where macos , window,linux)
# 5. in which language python is develop?
# ans : Cpython is develop in c language.
#       Jpython is develop in java.
#       pypy is develop in python.
# 6. which language is fastest out of c,c++,java,python?
#     c is fastest
#     c++
#    java
#    python(slowest)

# %%
# First Example:

print("Hello World!") # print() is used to display information on the screen.
# Out:
# Hello World!

# %% [markdown]
# # Variables in python

# %%
A variable is name given to a memory location where we can store the data.
.The value in the variable can be changed during the program
. in python we dont need to declare the types of varaible its automatically understands the datatype.
   Syntax: 
. varaible_name = value

# %%
# Rules
. variable name can contain letters,underscore,numbers
. dont starts with number.
. case senstivite (name and Name are different)
. no spaces are allowes(use_instead of)
. Reserved key are not used(if,else,for)

# %%
# examples 
#valid names   
name
_total
asma_kauser
x2
num1
# invalid names
1names
total@
asma kauser
2x
class (keywords are not be used)
asma-kauser

# %%
Types of variables
. int = whole numbers
. string = text
. float = decimal
. bool =True or False
. list = collection of items []
. tuple = collection items ()
. set = unorder collection {}
. dict = key- values {"name":"Asma"}

# %%
#Examples:
name = "Asma"
age = 22
marks = 80.5
is_student = True
hobbies = ["rerading","playing"]
print(type(name))
print(type(age))
print(type(marks))
print(type(is_student))
print(type(hobbies))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'list'>

# %%
name = "Asma"
age = 22
marks = 80.5
is_student = True
hobbies = ["rerading","playing"]
print(name)
print(age)
print(marks)
print(is_student)
print(hobbies)
# Out:
# Asma
# 22
# 80.5
# True
# ['rerading', 'playing']

# %%
# delete variable
name = "Asma"
age = 22
marks = 80.5
is_student = True
hobbies = ["rerading","playing"]
del(hobbies)
print(name)
print(age)
print(marks)
print(is_student)
# Out:
# Asma
# 22
# 80.5
# True
